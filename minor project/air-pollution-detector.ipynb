# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/airquality/AirQuality.xlsx

# %%
Air_Quality = pd.read_excel("/kaggle/input/airquality/AirQuality.xlsx")

# %%
Air_Quality.head()
# Out:
#   Country           State       city                           place  \
# 0   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
# 1   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
# 2   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
# 3   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
# 4   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
#
#             lastupdate   Avg    Max   Min Pollutants
# 0  21-12-2018 03:00:00  70.0  108.0  42.0      PM2.5
# 1  21-12-2018 03:00:00  76.0  102.0  43.0       PM10
# 2  21-12-2018 03:00:00  73.0  118.0  46.0        NO2
# 3  21-12-2018 03:00:00   5.0    6.0   4.0        NH3
# 4  21-12-2018 03:00:00  41.0  109.0   2.0        SO2

# %%
print(type(Air_Quality))
print(Air_Quality.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['Country', 'State', 'city', 'place', 'lastupdate', 'Avg', 'Max', 'Min',
#        'Pollutants'],
#       dtype='object')

# %%
Air_Quality
# Out:
#     Country           State       city                               place  \
# 0     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 1     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 2     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 3     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 4     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# ..      ...             ...        ...                                 ...
# 819   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 820   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 821   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 822   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 823   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
#
#               lastupdate   Avg    Max   Min Pollutants
# 0    21-12-2018 03:00:00  70.0  108.0  42.0      PM2.5
# 1    21-12-2018 03:00:00  76.0  102.0  43.0       PM10
# 2    21-12-2018 03:00:00  73.0  118.0  46.0        NO2
# 3    21-12-2018 03:00:00   5.0    6.0   4.0        NH3
# 4    21-12-2018 03:00:00  41.0  109.0   2.0        SO2
# ..                   ...   ...    ...   ...        ...
# 819  21-12-2018 03:00:00  49.0   83.0  14.0        NO2
# 820  21-12-2018 03:00:00   8.0   13.0   2.0        NH3
# 821  21-12-2018 03:00:00   5.0    8.0   2.0        SO2
# 822  21-12-2018 03:00:00  33.0   67.0  14.0         CO
# 823  21-12-2018 03:00:00  33.0   65.0   7.0      OZONE
#
# [824 rows x 9 columns]

# %%
print(Air_Quality.index)
# Out:
# RangeIndex(start=0, stop=824, step=1)

# %%
print(Air_Quality['Country'])
# Out:
# 0      India
# 1      India
# 2      India
# 3      India
# 4      India
#        ...
# 819    India
# 820    India
# 821    India
# 822    India
# 823    India
# Name: Country, Length: 824, dtype: object

# %%
print(Air_Quality['State'])
# Out:
# 0      Andhra_Pradesh
# 1      Andhra_Pradesh
# 2      Andhra_Pradesh
# 3      Andhra_Pradesh
# 4      Andhra_Pradesh
#             ...
# 819       West_Bengal
# 820       West_Bengal
# 821       West_Bengal
# 822       West_Bengal
# 823       West_Bengal
# Name: State, Length: 824, dtype: object

# %%
print(Air_Quality.State.unique())
# Out:
# ['Andhra_Pradesh' 'Bihar' 'Delhi' 'Gujarat' 'Haryana' 'Jharkhand'
#  'Karnataka' 'Kerala' 'Madhya Pradesh' 'Maharashtra' 'Odisha' 'Punjab'
#  'Rajasthan' 'TamilNadu' 'Telangana' 'Uttar_Pradesh' 'West_Bengal']

# %%
print(Air_Quality.Pollutants.unique())
# Out:
# ['PM2.5' 'PM10' 'NO2' 'NH3' 'SO2' 'CO' 'OZONE']

# %%
print(Air_Quality.head())
print()
print()
print(Air_Quality.describe())
# Out:
#   Country           State       city                           place  \
# 0   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
# 1   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
# 2   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
# 3   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
# 4   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
#
#             lastupdate   Avg    Max   Min Pollutants
# 0  21-12-2018 03:00:00  70.0  108.0  42.0      PM2.5
# 1  21-12-2018 03:00:00  76.0  102.0  43.0       PM10
# 2  21-12-2018 03:00:00  73.0  118.0  46.0        NO2
# 3  21-12-2018 03:00:00   5.0    6.0   4.0        NH3
# 4  21-12-2018 03:00:00  41.0  109.0   2.0        SO2
#
#
#               Avg         Max         Min
# count  788.000000  788.000000  788.000000
# mean    96.736041  149.675127   50.855330
# std    114.746642  150.264480   74.279885
# min      1.000000    1.000000    1.000000
# 25%     20.000000   35.000000    7.000000
# 50%     50.000000  103.000000   20.000000
# 75%    108.000000  180.250000   54.000000
# max    457.000000  500.000000  335.000000

# %% [markdown]
# **GROUPING BY STATES**

# %%
group_of_States = Air_Quality.groupby('State')
group_of_States.head()
# Out:
#     Country           State       city                                place  \
# 0     India  Andhra_Pradesh  Amaravati       Secretariat, Amaravati - APPCB
# 1     India  Andhra_Pradesh  Amaravati       Secretariat, Amaravati - APPCB
# 2     India  Andhra_Pradesh  Amaravati       Secretariat, Amaravati - APPCB
# 3     India  Andhra_Pradesh  Amaravati       Secretariat, Amaravati - APPCB
# 4     India  Andhra_Pradesh  Amaravati       Secretariat, Amaravati - APPCB
# ..      ...             ...        ...                                  ...
# 774   India     West_Bengal     Asanol  Asansol Court Area, Asansol - WBPCB
# 775   India     West_Bengal     Asanol  Asansol Court Area, Asansol - WBPCB
# 776   India     West_Bengal     Asanol  Asansol Court Area, Asansol - WBPCB
# 777   India     West_Bengal     Asanol  Asansol Court Area, Asansol - WBPCB
# 778   India     West_Bengal     Asanol  Asansol Court Area, Asansol - WBPCB
#
#               lastupdate    Avg    Max    Min Pollutants
# 0    21-12-2018 03:00:00   70.0  108.0   42.0      PM2.5
# 1    21-12-2018 03:00:00   76.0  102.0   43.0       PM10
# 2    21-12-2018 03:00:00   73.0  118.0   46.0        NO2
# 3    21-12-2018 03:00:00    5.0    6.0    4.0        NH3
# 4    21-12-2018 03:00:00   41.0  109.0    2.0        SO2
# ..                   ...    ...    ...    ...        ...
# 774  21-12-2018 03:00:00  287.0  350.0  140.0      PM2.5
# 775  21-12-2018 03:00:00  180.0  364.0  131.0       PM10
# 776  21-12-2018 03:00:00   69.0  107.0   38.0        NO2
# 777  21-12-2018 03:00:00    4.0    7.0    1.0        NH3
# 778  21-12-2018 03:00:00    9.0   51.0    1.0        SO2
#
# [85 rows x 9 columns]

# %%
Air_Quality.head(5)
# Out:
#   Country           State       city                           place  \
# 0   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
# 1   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
# 2   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
# 3   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
# 4   India  Andhra_Pradesh  Amaravati  Secretariat, Amaravati - APPCB
#
#             lastupdate   Avg    Max   Min Pollutants
# 0  21-12-2018 03:00:00  70.0  108.0  42.0      PM2.5
# 1  21-12-2018 03:00:00  76.0  102.0  43.0       PM10
# 2  21-12-2018 03:00:00  73.0  118.0  46.0        NO2
# 3  21-12-2018 03:00:00   5.0    6.0   4.0        NH3
# 4  21-12-2018 03:00:00  41.0  109.0   2.0        SO2

# %%
group_of_States.head([5])
# Out:
#     Country           State       city                                place  \
# 0     India  Andhra_Pradesh  Amaravati       Secretariat, Amaravati - APPCB
# 1     India  Andhra_Pradesh  Amaravati       Secretariat, Amaravati - APPCB
# 2     India  Andhra_Pradesh  Amaravati       Secretariat, Amaravati - APPCB
# 3     India  Andhra_Pradesh  Amaravati       Secretariat, Amaravati - APPCB
# 4     India  Andhra_Pradesh  Amaravati       Secretariat, Amaravati - APPCB
# ..      ...             ...        ...                                  ...
# 774   India     West_Bengal     Asanol  Asansol Court Area, Asansol - WBPCB
# 775   India     West_Bengal     Asanol  Asansol Court Area, Asansol - WBPCB
# 776   India     West_Bengal     Asanol  Asansol Court Area, Asansol - WBPCB
# 777   India     West_Bengal     Asanol  Asansol Court Area, Asansol - WBPCB
# 778   India     West_Bengal     Asanol  Asansol Court Area, Asansol - WBPCB
#
#               lastupdate    Avg    Max    Min Pollutants
# 0    21-12-2018 03:00:00   70.0  108.0   42.0      PM2.5
# 1    21-12-2018 03:00:00   76.0  102.0   43.0       PM10
# 2    21-12-2018 03:00:00   73.0  118.0   46.0        NO2
# 3    21-12-2018 03:00:00    5.0    6.0    4.0        NH3
# 4    21-12-2018 03:00:00   41.0  109.0    2.0        SO2
# ..                   ...    ...    ...    ...        ...
# 774  21-12-2018 03:00:00  287.0  350.0  140.0      PM2.5
# 775  21-12-2018 03:00:00  180.0  364.0  131.0       PM10
# 776  21-12-2018 03:00:00   69.0  107.0   38.0        NO2
# 777  21-12-2018 03:00:00    4.0    7.0    1.0        NH3
# 778  21-12-2018 03:00:00    9.0   51.0    1.0        SO2
#
# [85 rows x 9 columns]

# %%
states_pollution = Air_Quality.groupby(['State','Pollutants'])

# %%
states_pollution.head()
# Out:
#     Country           State       city  \
# 0     India  Andhra_Pradesh  Amaravati
# 1     India  Andhra_Pradesh  Amaravati
# 2     India  Andhra_Pradesh  Amaravati
# 3     India  Andhra_Pradesh  Amaravati
# 4     India  Andhra_Pradesh  Amaravati
# ..      ...             ...        ...
# 805   India     West_Bengal    Kolkata
# 806   India     West_Bengal    Kolkata
# 809   India     West_Bengal    Kolkata
# 810   India     West_Bengal    Kolkata
# 813   India     West_Bengal    Kolkata
#
#                                             place           lastupdate    Avg  \
# 0                  Secretariat, Amaravati - APPCB  21-12-2018 03:00:00   70.0
# 1                  Secretariat, Amaravati - APPCB  21-12-2018 03:00:00   76.0
# 2                  Secretariat, Amaravati - APPCB  21-12-2018 03:00:00   73.0
# 3                  Secretariat, Amaravati - APPCB  21-12-2018 03:00:00    5.0
# 4                  Secretariat, Amaravati - APPCB  21-12-2018 03:00:00   41.0
# ..                                            ...                  ...    ...
# 805  Rabindra Bharati University, Kolkata - WBPCB  21-12-2018 03:00:00   94.0
# 806  Rabindra Bharati University, Kolkata - WBPCB  21-12-2018 03:00:00    3.0
# 809  Rabindra Bharati University, Kolkata - WBPCB  21-12-2018 03:00:00  154.0
# 810                     Victoria, Kolkata - WBPCB  21-12-2018 03:00:00  280.0
# 813                     Victoria, Kolkata - WBPCB  21-12-2018 03:00:00   26.0
#
#        Max    Min Pollutants
# 0    108.0   42.0      PM2.5
# 1    102.0   43.0       PM10
# 2    118.0   46.0        NO2
# 3      6.0    4.0        NH3
# 4    109.0    2.0        SO2
# ..     ...    ...        ...
# 805  158.0   47.0        NO2
# 806    5.0    1.0        NH3
# 809  154.0    1.0      OZONE
# 810  377.0  165.0      PM2.5
# 813   56.0    6.0        NH3
#
# [435 rows x 9 columns]

# %%
state_quality = Air_Quality.groupby(['State', 'Pollutants'])

# %%
state_quality.head(10)
# Out:
#     Country           State       city                               place  \
# 0     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 1     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 2     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 3     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 4     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# ..      ...             ...        ...                                 ...
# 819   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 820   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 821   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 822   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 823   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
#
#               lastupdate   Avg    Max   Min Pollutants
# 0    21-12-2018 03:00:00  70.0  108.0  42.0      PM2.5
# 1    21-12-2018 03:00:00  76.0  102.0  43.0       PM10
# 2    21-12-2018 03:00:00  73.0  118.0  46.0        NO2
# 3    21-12-2018 03:00:00   5.0    6.0   4.0        NH3
# 4    21-12-2018 03:00:00  41.0  109.0   2.0        SO2
# ..                   ...   ...    ...   ...        ...
# 819  21-12-2018 03:00:00  49.0   83.0  14.0        NO2
# 820  21-12-2018 03:00:00   8.0   13.0   2.0        NH3
# 821  21-12-2018 03:00:00   5.0    8.0   2.0        SO2
# 822  21-12-2018 03:00:00  33.0   67.0  14.0         CO
# 823  21-12-2018 03:00:00  33.0   65.0   7.0      OZONE
#
# [630 rows x 9 columns]

# %% [markdown]
# **MEAN OF POLLUTION IN STATES**

# %%
Mean_Pollution = group_of_States.mean()
Mean_Pollution
# Out:
#                        Avg         Max        Min
# State
# Andhra_Pradesh   41.321429   64.285714  23.928571
# Bihar           121.357143  165.142857  74.071429
# Delhi           139.072961  195.892704  80.339056
# Gujarat         106.500000  173.250000  47.500000
# Haryana          80.653846  143.076923  31.576923
# Jharkhand        84.000000  136.200000  42.200000
# Karnataka        51.295082   84.606557  23.803279
# Kerala           67.000000   97.857143  44.000000
# Madhya Pradesh   78.589744  142.974359  31.846154
# Maharashtra      62.981132  121.735849  26.528302
# Odisha           54.727273  113.090909  26.181818
# Punjab           55.938776   89.102041  32.795918
# Rajasthan        80.647059  153.220588  28.352941
# TamilNadu        36.333333   79.666667  15.200000
# Telangana        48.457143   85.228571  23.057143
# Uttar_Pradesh   135.633333  194.166667  75.733333
# West_Bengal      94.980000  150.780000  46.880000

# %%
Mean_Pollution.sort_values(by=['Avg'])
# Out:
#                        Avg         Max        Min
# State
# TamilNadu        36.333333   79.666667  15.200000
# Andhra_Pradesh   41.321429   64.285714  23.928571
# Telangana        48.457143   85.228571  23.057143
# Karnataka        51.295082   84.606557  23.803279
# Odisha           54.727273  113.090909  26.181818
# Punjab           55.938776   89.102041  32.795918
# Maharashtra      62.981132  121.735849  26.528302
# Kerala           67.000000   97.857143  44.000000
# Madhya Pradesh   78.589744  142.974359  31.846154
# Rajasthan        80.647059  153.220588  28.352941
# Haryana          80.653846  143.076923  31.576923
# Jharkhand        84.000000  136.200000  42.200000
# West_Bengal      94.980000  150.780000  46.880000
# Gujarat         106.500000  173.250000  47.500000
# Bihar           121.357143  165.142857  74.071429
# Uttar_Pradesh   135.633333  194.166667  75.733333
# Delhi           139.072961  195.892704  80.339056

# %% [markdown]
# **TYPE**

# %%
type(Mean_Pollution)
# Out:
# pandas.core.frame.DataFrame

# %%
type(Air_Quality)
# Out:
# pandas.core.frame.DataFrame

# %%
type(group_of_States)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
type(state_quality)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# **MAKE DATAFRAME**

# %%
group_of_States_df = pd.DataFrame(group_of_States)
Air_Quality_df = pd.DataFrame(Air_Quality)

# %%
group_of_States_df
# Out:
#                  0                                                  1
# 0   Andhra_Pradesh     Country           State               city ...
# 1            Bihar     Country  State         city                ...
# 2            Delhi      Country  State   city                   pl...
# 3          Gujarat      Country    State       city               ...
# 4          Haryana      Country    State       city               ...
# 5        Jharkhand      Country      State        city            ...
# 6        Karnataka      Country      State       city             ...
# 7           Kerala      Country   State                city  \
# 393...
# 8   Madhya Pradesh      Country           State       city  \
# 400 ...
# 9      Maharashtra      Country        State        city          ...
# 10          Odisha      Country   State          city             ...
# 11          Punjab      Country   State              city  \
# 511  ...
# 12       Rajasthan      Country      State     city               ...
# 13       TamilNadu      Country      State     city               ...
# 14       Telangana      Country      State       city  \
# 644   Ind...
# 15   Uttar_Pradesh      Country          State      city          ...
# 16     West_Bengal      Country        State      city  \
# 774   In...

# %%
Air_Quality_df
# Out:
#     Country           State       city                               place  \
# 0     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 1     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 2     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 3     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# 4     India  Andhra_Pradesh  Amaravati      Secretariat, Amaravati - APPCB
# ..      ...             ...        ...                                 ...
# 819   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 820   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 821   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 822   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
# 823   India     West_Bengal   Siliguri  Ward-32 Bapupara, Siliguri - WBPCB
#
#               lastupdate   Avg    Max   Min Pollutants
# 0    21-12-2018 03:00:00  70.0  108.0  42.0      PM2.5
# 1    21-12-2018 03:00:00  76.0  102.0  43.0       PM10
# 2    21-12-2018 03:00:00  73.0  118.0  46.0        NO2
# 3    21-12-2018 03:00:00   5.0    6.0   4.0        NH3
# 4    21-12-2018 03:00:00  41.0  109.0   2.0        SO2
# ..                   ...   ...    ...   ...        ...
# 819  21-12-2018 03:00:00  49.0   83.0  14.0        NO2
# 820  21-12-2018 03:00:00   8.0   13.0   2.0        NH3
# 821  21-12-2018 03:00:00   5.0    8.0   2.0        SO2
# 822  21-12-2018 03:00:00  33.0   67.0  14.0         CO
# 823  21-12-2018 03:00:00  33.0   65.0   7.0      OZONE
#
# [824 rows x 9 columns]

# %% [markdown]
# **HISTOGRAM PLOT FOR AVERAGE OF AIR QUALITY **

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
plt.hist(Air_Quality_df.Avg, histtype='bar', rwidth=0.7)
plt.xlabel('AVERAGE')
plt.ylabel('COUNT')
plt.title('AVERAGE OF AIR QUALITY IN INDIA')
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /opt/conda/lib/python3.6/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# **HISTOGRAM PLOT FOR CHECKING AIR QUALITY IN STATES**

# %%
plt.figure(figsize=(17,7), dpi=100)
sns.countplot(x='State',data=Air_Quality)
plt.xlabel('State')
plt.tight_layout()

# %% [markdown]
# **HISTOGRAM OF MAXIMUM OF AIR QUALITY**

# %%
plt.hist(Air_Quality_df.Max, histtype ='bar', rwidth=0.7)
plt.xlabel("MAX")
plt.ylabel("COUNT")
plt.title("MAX OF AIR QUALITY OF INDIA")
plt.show()

# %% [markdown]
# **HISTOGRAM OF MINIMUM OF AIR QUALITY**

# %%
plt.hist(Air_Quality_df.Min, histtype ='bar', rwidth=0.7)
plt.xlabel("Min")
plt.ylabel("COUNT")
plt.title("Min OF AIR QUALITY OF INDIA")
plt.show()

# %% [markdown]
# **PLOTTING OF TYPES OF POLLUTANTS**

# %%
Air_Quality['Pollutants'].value_counts().plot()
plt.xlabel("Pollutants")
plt.ylabel("COUNT")
plt.title("Pollutants OF AIR QUALITY OF INDIA")
print(plt.show())
Air_Quality['Pollutants'].value_counts().plot('bar')
plt.xlabel("Pollutants")
plt.ylabel("COUNT")
plt.title("Pollutants OF AIR QUALITY OF INDIA")
print(plt.show())
# Out:
# None
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
# None

# %% [markdown]
# **PLOTTING OF COUNT EACH POLLUTANT IN  STATE**

# %%
import seaborn as sns
pollutant = list(Air_Quality['Pollutants'].unique())
for poll in pollutant:
    plt.figure(figsize=(18,8), dpi = 100)
    sns.countplot(Air_Quality[Air_Quality['Pollutants'] == poll]['State'], data = Air_Quality)
    plt.tight_layout()
    plt.title(poll)
